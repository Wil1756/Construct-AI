# %%
# !git clone https://github.com/Wil1756/Construct-AI.git /content/construct-ai
# Out:
# Cloning into '/content/construct-ai'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 28 (delta 3), reused 23 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (28/28), 64.72 KiB | 753.00 KiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/content/construct-ai/data/raw/equipment_sensor_data.csv")

df.head()

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 1000
# Columns: 8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   engine_temperature  1000 non-null   float64
#  1   oil_temperature     1000 non-null   float64
#  2   hydraulic_pressure  1000 non-null   float64
#  3   vibration           1000 non-null   float64
#  4   engine_rpm          1000 non-null   float64
#  5   fuel_consumption    1000 non-null   float64
#  6   operating_hours     1000 non-null   int64
#  7   failure             1000 non-null   int64
# dtypes: float64(6), int64(2)
# memory usage: 62.6 KB

# %%
df.describe()
# Out:
#        engine_temperature  oil_temperature  hydraulic_pressure    vibration  \
# count         1000.000000      1000.000000         1000.000000  1000.000000
# mean            85.193321        90.566690          180.145855     2.977537
# std              9.792159         7.979635           24.586357     1.232559
# min             52.587327        66.476891          104.512196    -0.515338
# 25%             78.524097        85.150066          163.800010     2.115095
# 50%             85.253006        90.504617          179.993731     3.000221
# 75%             91.479439        95.831057          196.522883     3.800334
# max            123.527315       115.544861          278.155943     6.891712
#
#         engine_rpm  fuel_consumption  operating_hours      failure
# count  1000.000000       1000.000000      1000.000000  1000.000000
# mean   1785.217908         14.859787      4931.910000     0.155000
# std     297.714064          3.022168      2855.484219     0.362086
# ...

# %%
df.isnull().sum()
# Out:
# engine_temperature    0
# oil_temperature       0
# hydraulic_pressure    0
# vibration             0
# engine_rpm            0
# fuel_consumption      0
# operating_hours       0
# failure               0
# dtype: int64

# %%
df["failure"].value_counts().plot(kind="bar")

plt.title("Normal vs Failure")
plt.xlabel("Failure")
plt.ylabel("Number of Machines")
plt.show()

# %%
df.hist(figsize=(12, 10))

plt.tight_layout()
plt.show()

# %%
#check the correlation 
plt.figure(figsize=(10, 7))

sns.heatmap(df.corr(), annot=True, cmap="coolwarm")

plt.title("Feature Correlation")
plt.show()

# %%
# compare vibration

sns.boxplot(data=df, x="failure", y="vibration")

plt.title("Vibration vs Failure")
plt.xlabel("Failure")
plt.ylabel("Vibration")
plt.show()

# %%
# compare temp

sns.boxplot(data=df, x="failure", y="engine_temperature")

plt.title("Engine Temperature vs Failure")
plt.xlabel("Failure")
plt.ylabel("Engine Temperature")
plt.show()
